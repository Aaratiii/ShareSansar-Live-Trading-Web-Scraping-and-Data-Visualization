# %%
from bs4 import BeautifulSoup
import requests

url = BeautifulSoup('https://www.sharesansar.com/live-trading', 'html.parser')
soup = requests.get(url)
code = BeautifulSoup(soup.text,"lxml")
code
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_29496\2350202639.py:4: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   url = BeautifulSoup('https://www.sharesansar.com/live-trading', 'html.parser')
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, user-scalable=no, initial-scale = 1.0, minimum-scale=1.0, maximum-scale = 1.0" name="viewport"/>
# ...

# %%
code_table = code.table
code_table
# Out:
# <table class="table table-bordered table-striped table-hover dataTable compact" id="headFixed">
# <thead>
# <tr>
# <th width="10px">S.No</th>
# <th>Symbol</th>
# <th class="text-center">LTP</th>
# <th class="text-center">Point Change</th>
# <th class="text-center">% Change</th>
# <th class="text-center">Open</th>
# <th class="text-center">High</th>
# <th class="text-center">Low</th>
# <th class="text-center">Volume</th>
# <th class="text-center">Prev. Close</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="danger-index">
#                                         1</td>
# <td class="danger-index">
# <a href="https://www.sharesansar.com/company/aclbsl" title="ACLBSL">ACLBSL</a>
# </td>
# <td class="text-center danger-index">
#                                         1,049.00</td>
# <td class="text-center danger-index">
#                                         -11.10</td>
# <td class="text-center danger-index">
#                                         -1.05</td>
# ...

# %%
tags = code_table.find_all('tr')
tags
# Out:
# [<tr>
#  <th width="10px">S.No</th>
#  <th>Symbol</th>
#  <th class="text-center">LTP</th>
#  <th class="text-center">Point Change</th>
#  <th class="text-center">% Change</th>
#  <th class="text-center">Open</th>
#  <th class="text-center">High</th>
#  <th class="text-center">Low</th>
#  <th class="text-center">Volume</th>
#  <th class="text-center">Prev. Close</th>
#  </tr>,
#  <tr>
#  <td class="danger-index">
#                                          1</td>
#  <td class="danger-index">
#  <a href="https://www.sharesansar.com/company/aclbsl" title="ACLBSL">ACLBSL</a>
#  </td>
#  <td class="text-center danger-index">
#                                          1,049.00</td>
#  <td class="text-center danger-index">
#                                          -11.10</td>
#  <td class="text-center danger-index">
#                                          -1.05</td>
#  <td class="text-center danger-index">
#                                          1,060.00</td>
# ...

# %%
data = []
for tag in tags:
  data.append(tag.text.replace('\n                                        ',''))

data
# Out:
# ['\nS.No\nSymbol\nLTP\nPoint Change\n% Change\nOpen\nHigh\nLow\nVolume\nPrev. Close\n',
#  '\n1\n\nACLBSL\n\n1,049.00\n-11.10\n-1.05\n1,060.00\n1,060.00\n1,048.00\n1,146.00\n1,060.10\n',
#  '\n2\n\nADBL\n\n282.00\n-3.87\n-1.35\n289.50\n290.00\n280.00\n22,003.00\n285.87\n',
#  '\n3\n\nAHL\n\n720.00\n-25.47\n-3.42\n734.00\n734.00\n720.00\n3,315.00\n745.47\n',
#  '\n4\n\nAHPC\n\n244.50\n-7.73\n-3.06\n250.00\n255.00\n242.50\n94,763.00\n252.23\n',
#  '\n5\n\nAKJCL\n\n199.50\n-4.65\n-2.28\n200.10\n203.00\n199.00\n119,150.00\n204.15\n',
#  '\n6\n\nAKPL\n\n219.00\n-7.34\n-3.24\n225.10\n225.10\n218.00\n167,784.00\n226.34\n',
#  '\n7\n\nALBSL\n\n815.00\n-21.41\n-2.56\n822.00\n830.00\n815.00\n1,533.00\n836.41\n',
#  '\n8\n\nALICL\n\n718.00\n-8.21\n-1.13\n726.20\n726.20\n717.00\n12,586.00\n726.21\n',
#  '\n9\n\nANLB\n\n5,010.00\n-99.65\n-1.95\n5,009.90\n5,179.00\n5,007.50\n189.00\n5,109.65\n',
#  '\n10\n\nAPI\n\n261.20\n-8.45\n-3.13\n268.00\n268.00\n260.00\n132,218.00\n269.65\n',
# ...

# %%
data = []
for tag in tags:
  data.append(tag.text.split('\n                                        '))

data
# Out:
# [['\nS.No\nSymbol\nLTP\nPoint Change\n% Change\nOpen\nHigh\nLow\nVolume\nPrev. Close\n'],
#  ['\n',
#   '1\n\nACLBSL\n\n',
#   '1,049.00\n',
#   '-11.10\n',
#   '-1.05\n',
#   '1,060.00\n',
#   '1,060.00\n',
#   '1,048.00\n',
#   '1,146.00\n',
#   '1,060.10\n'],
#  ['\n',
#   '2\n\nADBL\n\n',
#   '282.00\n',
#   '-3.87\n',
#   '-1.35\n',
#   '289.50\n',
#   '290.00\n',
#   '280.00\n',
#   '22,003.00\n',
#   '285.87\n'],
#  ['\n',
#   '3\n\nAHL\n\n',
#   '720.00\n',
#   '-25.47\n',
#   '-3.42\n',
#   '734.00\n',
#   '734.00\n',
#   '720.00\n',
#   '3,315.00\n',
#   '745.47\n'],
#  ['\n',
#   '4\n\nAHPC\n\n',
#   '244.50\n',
#   '-7.73\n',
#   '-3.06\n',
#   '250.00\n',
#   '255.00\n',
#   '242.50\n',
#   '94,763.00\n',
#   '252.23\n'],
#  ['\n',
#   '5\n\nAKJCL\n\n',
#   '199.50\n',
#   '-4.65\n',
#   '-2.28\n',
#   '200.10\n',
#   '203.00\n',
#   '199.00\n',
#   '119,150.00\n',
#   '204.15\n'],
#  ['\n',
#   '6\n\nAKPL\n\n',
#   '219.00\n',
#   '-7.34\n',
#   '-3.24\n',
# ...

# %%
data = []
for tag in tags:
  data.append(tag.text.replace('                                        ',''))

data
# Out:
# ['\nS.No\nSymbol\nLTP\nPoint Change\n% Change\nOpen\nHigh\nLow\nVolume\nPrev. Close\n',
#  '\n\n1\n\nACLBSL\n\n\n1,049.00\n\n-11.10\n\n-1.05\n\n1,060.00\n\n1,060.00\n\n1,048.00\n\n1,146.00\n\n1,060.10\n',
#  '\n\n2\n\nADBL\n\n\n282.00\n\n-3.87\n\n-1.35\n\n289.50\n\n290.00\n\n280.00\n\n22,003.00\n\n285.87\n',
#  '\n\n3\n\nAHL\n\n\n720.00\n\n-25.47\n\n-3.42\n\n734.00\n\n734.00\n\n720.00\n\n3,315.00\n\n745.47\n',
#  '\n\n4\n\nAHPC\n\n\n244.50\n\n-7.73\n\n-3.06\n\n250.00\n\n255.00\n\n242.50\n\n94,763.00\n\n252.23\n',
#  '\n\n5\n\nAKJCL\n\n\n199.50\n\n-4.65\n\n-2.28\n\n200.10\n\n203.00\n\n199.00\n\n119,150.00\n\n204.15\n',
#  '\n\n6\n\nAKPL\n\n\n219.00\n\n-7.34\n\n-3.24\n\n225.10\n\n225.10\n\n218.00\n\n167,784.00\n\n226.34\n',
#  '\n\n7\n\nALBSL\n\n\n815.00\n\n-21.41\n\n-2.56\n\n822.00\n\n830.00\n\n815.00\n\n1,533.00\n\n836.41\n',
#  '\n\n8\n\nALICL\n\n\n718.00\n\n-8.21\n\n-1.13\n\n726.20\n\n726.20\n\n717.00\n\n12,586.00\n\n726.21\n',
# ...

# %%
data = []
for tag in tags[1:]:
  data.append(tag.text.replace('                                        ','').split('\n\n'))

data
# Out:
# [['',
#   '1',
#   'ACLBSL',
#   '\n1,049.00',
#   '-11.10',
#   '-1.05',
#   '1,060.00',
#   '1,060.00',
#   '1,048.00',
#   '1,146.00',
#   '1,060.10\n'],
#  ['',
#   '2',
#   'ADBL',
#   '\n282.00',
#   '-3.87',
#   '-1.35',
#   '289.50',
#   '290.00',
#   '280.00',
#   '22,003.00',
#   '285.87\n'],
#  ['',
#   '3',
#   'AHL',
#   '\n720.00',
#   '-25.47',
#   '-3.42',
#   '734.00',
#   '734.00',
#   '720.00',
#   '3,315.00',
#   '745.47\n'],
#  ['',
#   '4',
#   'AHPC',
#   '\n244.50',
#   '-7.73',
#   '-3.06',
#   '250.00',
#   '255.00',
#   '242.50',
#   '94,763.00',
#   '252.23\n'],
#  ['',
#   '5',
#   'AKJCL',
#   '\n199.50',
#   '-4.65',
#   '-2.28',
#   '200.10',
#   '203.00',
#   '199.00',
#   '119,150.00',
#   '204.15\n'],
#  ['',
#   '6',
#   'AKPL',
#   '\n219.00',
#   '-7.34',
#   '-3.24',
#   '225.10',
#   '225.10',
#   '218.00',
#   '167,784.00',
#   '226.34\n'],
#  ['',
#   '7',
#   'ALBSL',
#   '\n815.00',
#   '-21.41',
#   '-2.56',
#   '822.00',
#   '830.00',
# ...

# %%
data = []
for tag in tags[1:]:
  x = (tag.text.replace('                                        ','').split('\n\n'))
  data.append(x[1:])
data
# Out:
# [['1',
#   'ACLBSL',
#   '\n1,049.00',
#   '-11.10',
#   '-1.05',
#   '1,060.00',
#   '1,060.00',
#   '1,048.00',
#   '1,146.00',
#   '1,060.10\n'],
#  ['2',
#   'ADBL',
#   '\n282.00',
#   '-3.87',
#   '-1.35',
#   '289.50',
#   '290.00',
#   '280.00',
#   '22,003.00',
#   '285.87\n'],
#  ['3',
#   'AHL',
#   '\n720.00',
#   '-25.47',
#   '-3.42',
#   '734.00',
#   '734.00',
#   '720.00',
#   '3,315.00',
#   '745.47\n'],
#  ['4',
#   'AHPC',
#   '\n244.50',
#   '-7.73',
#   '-3.06',
#   '250.00',
#   '255.00',
#   '242.50',
#   '94,763.00',
#   '252.23\n'],
#  ['5',
#   'AKJCL',
#   '\n199.50',
#   '-4.65',
#   '-2.28',
#   '200.10',
#   '203.00',
#   '199.00',
#   '119,150.00',
#   '204.15\n'],
#  ['6',
#   'AKPL',
#   '\n219.00',
#   '-7.34',
#   '-3.24',
#   '225.10',
#   '225.10',
#   '218.00',
#   '167,784.00',
#   '226.34\n'],
#  ['7',
#   'ALBSL',
#   '\n815.00',
#   '-21.41',
#   '-2.56',
#   '822.00',
#   '830.00',
#   '815.00',
#   '1,533.00',
#   '836.41\n'],
#  ['8',
# ...

# %%
data = []
for tag in tags[1:]:
  x = tag.text.replace('                                        ','').split('\n\n')
  y = [i.replace('\n','') for i in x]
  data.append(y[1:])

data
# Out:
# [['1',
#   'ACLBSL',
#   '1,049.00',
#   '-11.10',
#   '-1.05',
#   '1,060.00',
#   '1,060.00',
#   '1,048.00',
#   '1,146.00',
#   '1,060.10'],
#  ['2',
#   'ADBL',
#   '282.00',
#   '-3.87',
#   '-1.35',
#   '289.50',
#   '290.00',
#   '280.00',
#   '22,003.00',
#   '285.87'],
#  ['3',
#   'AHL',
#   '720.00',
#   '-25.47',
#   '-3.42',
#   '734.00',
#   '734.00',
#   '720.00',
#   '3,315.00',
#   '745.47'],
#  ['4',
#   'AHPC',
#   '244.50',
#   '-7.73',
#   '-3.06',
#   '250.00',
#   '255.00',
#   '242.50',
#   '94,763.00',
#   '252.23'],
#  ['5',
#   'AKJCL',
#   '199.50',
#   '-4.65',
#   '-2.28',
#   '200.10',
#   '203.00',
#   '199.00',
#   '119,150.00',
#   '204.15'],
#  ['6',
#   'AKPL',
#   '219.00',
#   '-7.34',
#   '-3.24',
#   '225.10',
#   '225.10',
#   '218.00',
#   '167,784.00',
#   '226.34'],
#  ['7',
#   'ALBSL',
#   '815.00',
#   '-21.41',
#   '-2.56',
#   '822.00',
#   '830.00',
#   '815.00',
#   '1,533.00',
#   '836.41'],
#  ['8',
#   'ALICL',
#   '718.00',
# ...

# %%
col = tags[0].text.split('\n')[1:-1]
col
# Out:
# ['S.No',
#  'Symbol',
#  'LTP',
#  'Point Change',
#  '% Change',
#  'Open',
#  'High',
#  'Low',
#  'Volume',
#  'Prev. Close']

# %%
import pandas as pd
df = pd.DataFrame(data, columns= col)
df
# Out:
#     S.No  Symbol       LTP Point Change % Change      Open      High  \
# 0      1  ACLBSL  1,049.00       -11.10    -1.05  1,060.00  1,060.00
# 1      2    ADBL    282.00        -3.87    -1.35    289.50    290.00
# 2      3     AHL    720.00       -25.47    -3.42    734.00    734.00
# 3      4    AHPC    244.50        -7.73    -3.06    250.00    255.00
# 4      5   AKJCL    199.50        -4.65    -2.28    200.10    203.00
# ..   ...     ...       ...          ...      ...       ...       ...
# 306  307    USHL    730.30       -24.71    -3.27    770.00    770.00
# 307  308    USLB  1,622.00       -63.00    -3.74  1,670.00  1,684.00
# 308  309    VLBS    810.00       -30.78    -3.66    825.00    825.00
# 309  310   VLUCL    650.10       -24.48    -3.63    675.00    675.00
# 310  311    WNLB  3,000.00      -112.10    -3.60  3,095.80  3,100.00
#
#           Low      Volume Prev. Close
# 0    1,048.00    1,146.00    1,060.10
# 1      280.00   22,003.00      285.87
# ...

# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
